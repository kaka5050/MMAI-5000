# %% [markdown]
# ## Summary </br>
# Clustering the Co2 Emission Data for the car model.</br>

# %%
# import necessary tools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# ignore warnings
import warnings
warnings.filterwarnings(action="ignore")

# clustering
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.mixture import GaussianMixture
from matplotlib import cm
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
df = pd.read_excel(r"C:\Users\oscar\Downloads\Co2-Emission-Data.xlsx")

# %%
df
# Out:
#        MODEL Year   MAKE MODEL (# = high output engine)   VEHICLE CLASS  \
# 0            2000  ACURA                          1.6EL         COMPACT
# 1            2000  ACURA                          1.6EL         COMPACT
# 2            2000  ACURA                          3.2TL        MID-SIZE
# 3            2000  ACURA                          3.5RL        MID-SIZE
# 4            2000  ACURA                        INTEGRA      SUBCOMPACT
# ...           ...    ...                            ...             ...
# 14248        2014  VOLVO                       XC60 AWD     SUV - SMALL
# 14249        2014  VOLVO                       XC60 AWD     SUV - SMALL
# 14250        2014  VOLVO                       XC70 AWD     SUV - SMALL
# 14251        2014  VOLVO                       XC70 AWD     SUV - SMALL
# 14252        2014  VOLVO                       XC90 AWD  SUV - STANDARD
#
#        ENGINE SIZE (L)  CYLINDERS TRANSMISSION FUEL Type  \
# 0                  1.6          4           A4         X
# 1                  1.6          4           M5         X
# 2                  3.2          6          AS5         Z
# 3                  3.5          6           A4         Z
# 4                  1.8          4           A4         X
# ...                ...        ...          ...       ...
# 14248              3.0          6          AS6         X
# 14249              3.2          6          AS6         X
# 14250              3.0          6          AS6         X
# 14251              3.2          6          AS6         X
# 14252              3.2          6          AS6         X
#
#        FUEL CONSUMPTION CITY (L/100 km)  HWY (L/100 km)  COMB (L/100 km)  \
# 0                                   9.2             6.7              8.1
# 1                                   8.5             6.5              7.6
# 2                                  12.2             7.4             10.0
# 3                                  13.4             9.2             11.5
# 4                                  10.0             7.0              8.6
# ...                                 ...             ...              ...
# 14248                              11.9             8.3             10.3
# 14249                              11.7             8.0             10.0
# 14250                              11.9             8.3             10.3
# 14251                              11.4             7.8              9.8
# 14252                              13.3             8.6             11.2
#
#        COMB (mpg)  CO2 EMISSIONS (g/km)
# 0              35                   186
# 1              37                   175
# 2              28                   230
# 3              25                   264
# 4              33                   198
# ...           ...                   ...
# 14248          27                   237
# 14249          28                   230
# 14250          27                   237
# 14251          29                   225
# 14252          25                   258
#
# [14253 rows x 13 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
# Check missing data
df.isna().sum()
# Out:
# MODEL Year                          0
# MAKE                                0
# MODEL (# = high output engine)      0
# VEHICLE CLASS                       0
# ENGINE SIZE (L)                     0
# CYLINDERS                           0
# TRANSMISSION                        0
# FUEL Type                           0
# FUEL CONSUMPTION CITY (L/100 km)    0
# HWY (L/100 km)                      0
# COMB (L/100 km)                     0
# COMB (mpg)                          0
# CO2 EMISSIONS (g/km)                0
# dtype: int64

# %% [markdown]
# No missing Value in the data

# %%
# Check for duplicate Values
df.duplicated().sum()
# Out:
# 1

# %%
# Drop duplicated record
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14252 entries, 0 to 14252
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   MODEL Year                        14252 non-null  int64
#  1   MAKE                              14252 non-null  object
#  2   MODEL (# = high output engine)    14252 non-null  object
#  3   VEHICLE CLASS                     14252 non-null  object
#  4   ENGINE SIZE (L)                   14252 non-null  float64
#  5   CYLINDERS                         14252 non-null  int64
#  6   TRANSMISSION                      14252 non-null  object
#  7   FUEL Type                         14252 non-null  object
#  8   FUEL CONSUMPTION CITY (L/100 km)  14252 non-null  float64
#  9   HWY (L/100 km)                    14252 non-null  float64
#  10  COMB (L/100 km)                   14252 non-null  float64
#  11  COMB (mpg)                        14252 non-null  int64
#  12  CO2 EMISSIONS (g/km)              14252 non-null  int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# This data include both numeric and categorical data.

# %% [markdown]
# ## EDA

# %% [markdown]
# Numeric Variables

# %%
# Group numeric variables
numeric_df = df.select_dtypes(include=['number'])
numeric_df.columns
# Out:
# Index(['MODEL Year', 'ENGINE SIZE (L)', 'CYLINDERS',
#        'FUEL CONSUMPTION CITY (L/100 km)', 'HWY (L/100 km)', 'COMB (L/100 km)',
#        'COMB (mpg)', 'CO2 EMISSIONS (g/km)'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

columns_to_plot = numeric_df.columns[:8]  # Select the first eight columns

fig, axes = plt.subplots(4, 2, figsize=(20, 10))  # Set up a 4x2 subplot grid

# Flatten the axes array for easy iteration
axes_flat = axes.flatten()

# Iterate over the selected columns and their corresponding axes to plot
for col, ax in zip(columns_to_plot, axes_flat):
    sns.boxplot(x=col, data=numeric_df, ax=ax)

plt.tight_layout()  # Adjust the layout to make sure everything fits without overlap
plt.show()  # Display the plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the DataFrame to include only numeric columns
numeric_df = df.select_dtypes(include=['number'])

plt.figure(figsize=(12, 12))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', 
            xticklabels=numeric_df.columns,
            yticklabels=numeric_df.columns)
# Out:
# <Axes: >

# %% [markdown]
# Objectives:</br>
#
# Segmentation for Targeted Marketing and Product Development:
# Fuel Efficiency Focus: Clusters characterized by smaller fuel sizes and lower CO2 emissions can identify consumer segments that prioritize fuel economy and environmental friendliness. These insights can guide the development and marketing of eco-friendly vehicles, such as hybrids or fully electric models, targeting eco-conscious consumers. </br>
# Performance-Oriented Segments: Conversely, clusters with larger fuel sizes and higher CO2 emissions can pinpoint a market segment that values performance and may prefer larger, more powerful vehicles. This information helps in developing vehicles that meet these preferences while implementing technologies to improve their environmental impact. </br>

# %% [markdown]
# All the numeric variables are highly correlated.</br>
# Choose CO2 EMISSIONS (g/km) and ENGINE SIZE (L) as the variables for clustering.

# %%
import seaborn as sns

# Now, make a Seaborn pairplot with the correctly specified columns and the chosen color palette
sns.pairplot(numeric_df)

# %% [markdown]
# Drop outliers

# %%
# Calculate IQR for 'CO2 Emissions'
Q1_CO2 = df['CO2 EMISSIONS (g/km)'].quantile(0.25)
Q3_CO2 = df['CO2 EMISSIONS (g/km)'].quantile(0.75)
IQR_CO2 = Q3_CO2 - Q1_CO2
lower_bound_CO2 = Q1_CO2 - 1.5 * IQR_CO2
upper_bound_CO2 = Q3_CO2 + 1.5 * IQR_CO2

# Calculate IQR for 'HWY (L/100 km)'
Q1_HWY = df['HWY (L/100 km)'].quantile(0.25)
Q3_HWY = df['HWY (L/100 km)'].quantile(0.75)
IQR_HWY = Q3_HWY - Q1_HWY
lower_bound_HWY = Q1_HWY - 1.5 * IQR_HWY
upper_bound_HWY = Q3_HWY + 1.5 * IQR_HWY

limit = 7

# Filter out the outliers for both 'CO2 Emissions' and 'HWY (L/100 km)'
df_no_outliers = df[(df['CO2 EMISSIONS (g/km)'] >= lower_bound_CO2) & 
                    (df['CO2 EMISSIONS (g/km)'] <= upper_bound_CO2) &
                    (df['HWY (L/100 km)'] >= lower_bound_HWY) &
                    (df['HWY (L/100 km)'] <= upper_bound_HWY)&
                    (df['ENGINE SIZE (L)'] <= limit)]

# %%
df.shape
# Out:
# (14252, 13)

# %%
df_no_outliers.shape
# Out:
# (13733, 13)

# %% [markdown]
# ## Categorical Variable

# %%
df_no_outliers.columns
# Out:
# Index(['MODEL Year', 'MAKE', 'MODEL (# = high output engine)', 'VEHICLE CLASS',
#        'ENGINE SIZE (L)', 'CYLINDERS', 'TRANSMISSION', 'FUEL Type',
#        'FUEL CONSUMPTION CITY (L/100 km)', 'HWY (L/100 km)', 'COMB (L/100 km)',
#        'COMB (mpg)', 'CO2 EMISSIONS (g/km)'],
#       dtype='object')

# %%
unique_counts = df_no_outliers['MODEL Year'].value_counts()

# If you want to print the counts
print(unique_counts)
# Out:
# MODEL Year
# 2009    1048
# 2008    1041
# 2012    1037
# 2011    1031
# 2013    1014
# 2007    1011
# 2014    1010
# 2010     980
# 2005     974
# 2006     942
# 2004     862
# 2003     786
# 2002     699
# 2001     671
# 2000     627
# Name: count, dtype: int64

# %%
unique_counts = df_no_outliers['MAKE'].value_counts()

# If you want to print the counts
print(unique_counts)
# Out:
# MAKE
# CHEVROLET        1346
# FORD              967
# BMW               899
# GMC               836
# MERCEDES-BENZ     732
# DODGE             624
# TOYOTA            606
# VOLKSWAGEN        511
# NISSAN            493
# PORSCHE           488
# AUDI              477
# MAZDA             397
# VOLVO             376
# SUBARU            368
# CHRYSLER          342
# HYUNDAI           319
# HONDA             313
# KIA               286
# PONTIAC           253
# CADILLAC          250
# JEEP              249
# LEXUS             249
# MITSUBISHI        231
# JAGUAR            212
# SUZUKI            199
# MINI              196
# SAAB              190
# INFINITI          179
# ACURA             170
# BUICK             167
# SATURN            156
# LINCOLN           120
# LAND ROVER         87
# ASTON MARTIN       55
# MASERATI           44
# ROLLS-ROYCE        41
# BENTLEY            36
# LAMBORGHINI        34
# OLDSMOBILE         34
# DAEWOO             34
# RAM                33
# SCION              31
# FERRARI            26
# FIAT               20
# HUMMER             19
# ISUZU              18
# SMART              17
# PLYMOUTH            2
# ALFA ROMEO          1
# Name: count, dtype: int64

# %%
# Define the threshold
threshold_count = 80

# Filter the DataFrame to include only makes with counts above the threshold
df_no_outliers = df_no_outliers[df_no_outliers['MAKE'].isin(df_no_outliers['MAKE'].value_counts()[df_no_outliers['MAKE'].value_counts() >= threshold_count].index)]

# Print the counts of the makes in the filtered DataFrame to verify
print(df_no_outliers['MAKE'].value_counts())
# Out:
# MAKE
# CHEVROLET        1346
# FORD              967
# BMW               899
# GMC               836
# MERCEDES-BENZ     732
# DODGE             624
# TOYOTA            606
# VOLKSWAGEN        511
# NISSAN            493
# PORSCHE           488
# AUDI              477
# MAZDA             397
# VOLVO             376
# SUBARU            368
# CHRYSLER          342
# HYUNDAI           319
# HONDA             313
# KIA               286
# PONTIAC           253
# CADILLAC          250
# LEXUS             249
# JEEP              249
# MITSUBISHI        231
# JAGUAR            212
# SUZUKI            199
# MINI              196
# SAAB              190
# INFINITI          179
# ACURA             170
# BUICK             167
# SATURN            156
# LINCOLN           120
# LAND ROVER         87
# Name: count, dtype: int64

# %%
unique_counts = df_no_outliers['MODEL (# = high output engine)'].value_counts()

# If you want to print the counts
print(unique_counts)
# Out:
# MODEL (# = high output engine)
# JETTA                     74
# MUSTANG                   70
# RANGER                    61
# F150                      56
# SENTRA                    52
#                           ..
# IMPREZA GT TURBO           1
# IMPREZA GT WAGON TURBO     1
# LEGACY 2.5GT TURBO         1
# LEGACY 2.5i PZEV           1
# LEGACY AWD H6-3.0          1
# Name: count, Length: 2346, dtype: int64

# %%
unique_counts = df_no_outliers['VEHICLE CLASS'].value_counts()

# If you want to print the counts
print(unique_counts)
# Out:
# VEHICLE CLASS
# SUV                         2515
# COMPACT                     2042
# MID-SIZE                    1689
# PICKUP TRUCK - STANDARD     1357
# SUBCOMPACT                  1235
# FULL-SIZE                    767
# TWO-SEATER                   603
# STATION WAGON - SMALL        602
# MINICOMPACT                  576
# PICKUP TRUCK - SMALL         324
# STATION WAGON - MID-SIZE     320
# MINIVAN                      313
# SUV - SMALL                  294
# VAN - CARGO                  256
# SUV - STANDARD               198
# VAN - PASSENGER              181
# SPECIAL PURPOSE VEHICLE       16
# Name: count, dtype: int64

# %%
df_no_outliers = df_no_outliers[df_no_outliers['VEHICLE CLASS'] != 'SPECIAL PURPOSE VEHICLE']

# %%
vehicle_class_mapping = {
    'SUV': 'SUV_GROUP',
    'SUV - SMALL': 'SUV_GROUP',
    'SUV - STANDARD': 'SUV_GROUP',
    'VAN - CARGO': 'VAN_GROUP',
    'VAN - PASSENGER': 'VAN_GROUP'
}

# Replace the 'VEHICLE CLASS' values with the group identifiers
df_no_outliers['VEHICLE CLASS'] = df_no_outliers['VEHICLE CLASS'].replace(vehicle_class_mapping)

# %%
unique_counts = df['FUEL Type'].value_counts()

# If you want to print the counts
print(unique_counts)
# Out:
# FUEL Type
# X    7798
# Z    5547
# E     765
# D     110
# N      32
# Name: count, dtype: int64

# %%
# Assuming 'Category1' and 'Category2' are the categorical columns in your DataFrame df
cross_tab = pd.crosstab(df_no_outliers['VEHICLE CLASS'], df_no_outliers['FUEL Type'])

# This will print the cross-tabulation to your console
print(cross_tab)
# Out:
# FUEL Type                  D    E   N     X    Z
# VEHICLE CLASS
# COMPACT                   32   24   1  1039  946
# FULL-SIZE                  2   53   2   371  339
# MID-SIZE                  12   53   0   914  710
# MINICOMPACT                0    0   0    30  546
# MINIVAN                    0   41   0   269    3
# PICKUP TRUCK - SMALL       0    8   0   316    0
# PICKUP TRUCK - STANDARD    0  117   4  1173   63
# STATION WAGON - MID-SIZE   1    1   0   121  197
# STATION WAGON - SMALL      9    0   0   315  278
# SUBCOMPACT                14    3   1   406  811
# SUV_GROUP                 35  153   0  2176  643
# TWO-SEATER                 0    0   0     9  594
# VAN_GROUP                  0    2  14   421    0

# %% [markdown]
# Frop N and D fuel type since they are outlier

# %%
# List of values you want to drop
values_to_drop = ['N', 'D']

# Drop rows where 'Column_Name' matches any value in 'values_to_drop'
df_filtered = df_no_outliers[~df_no_outliers['FUEL Type'].isin(values_to_drop)]

# %%
df_filtered.shape
# Out:
# (13145, 13)

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13145 entries, 0 to 14252
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   MODEL Year                        13145 non-null  int64
#  1   MAKE                              13145 non-null  object
#  2   MODEL (# = high output engine)    13145 non-null  object
#  3   VEHICLE CLASS                     13145 non-null  object
#  4   ENGINE SIZE (L)                   13145 non-null  float64
#  5   CYLINDERS                         13145 non-null  int64
#  6   TRANSMISSION                      13145 non-null  object
#  7   FUEL Type                         13145 non-null  object
#  8   FUEL CONSUMPTION CITY (L/100 km)  13145 non-null  float64
#  9   HWY (L/100 km)                    13145 non-null  float64
#  10  COMB (L/100 km)                   13145 non-null  float64
#  11  COMB (mpg)                        13145 non-null  int64
#  12  CO2 EMISSIONS (g/km)              13145 non-null  int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 1.4+ MB

# %%
df_filtered.columns
# Out:
# Index(['MODEL Year', 'MAKE', 'MODEL (# = high output engine)', 'VEHICLE CLASS',
#        'ENGINE SIZE (L)', 'CYLINDERS', 'TRANSMISSION', 'FUEL Type',
#        'FUEL CONSUMPTION CITY (L/100 km)', 'HWY (L/100 km)', 'COMB (L/100 km)',
#        'COMB (mpg)', 'CO2 EMISSIONS (g/km)'],
#       dtype='object')

# %% [markdown]
# Create the df for clustering

# %%
df_filtered1 = df_filtered[['MODEL Year','VEHICLE CLASS', 'FUEL Type', 'ENGINE SIZE (L)', 'CO2 EMISSIONS (g/km)', 'MAKE']]

# %%
import pandas as pd

# Perform one-hot encoding on 'VEHICLE CLASS' and 'FUEL Type'
df_encoded1 = pd.get_dummies(df_filtered1, columns=['VEHICLE CLASS', 'FUEL Type', 'MAKE'])

# %% [markdown]
# ## Clustering: K-Mean

# %%
# inertia plotter function
def inertia_plot(clust, X, start = 2, stop = 20):
    inertia = []
    for x in range(start,stop):
        km = clust(n_clusters = x)
        labels = km.fit_predict(X)
        inertia.append(km.inertia_)
    plt.figure(figsize = (12,6))
    plt.plot(range(start,stop), inertia, marker = 'o')
    plt.xlabel('Number of Clusters')
    plt.ylabel('Inertia')
    plt.title('Inertia plot with K')
    plt.xticks(list(range(start, stop)))
    plt.show()

# %%
inertia_plot(KMeans, df_encoded1)

# %% [markdown]
# Cluster of 5 looks like the best

# %%
# Calculate silhouette score for different clusters
def silh_samp_cluster(clust,  X, start=2, stop=5, metric = 'euclidean'):
    for x in range(start, stop):
        km = clust(n_clusters = x)
        y_km = km.fit_predict(X)
        cluster_labels = np.unique(y_km)
        n_clusters = cluster_labels.shape[0]
        silhouette_vals = silhouette_samples(X, y_km, metric = metric)
        y_ax_lower, y_ax_upper =0,0
        yticks = []
        for i, c in enumerate(cluster_labels):
            c_silhouette_vals = silhouette_vals[y_km == c]
            c_silhouette_vals.sort()
            y_ax_upper += len(c_silhouette_vals)
            color = cm.jet(float(i)/n_clusters)
            plt.barh(range(y_ax_lower, y_ax_upper),
                    c_silhouette_vals,
                    height=1.0,
                    edgecolor='none',
                    color = color)
            yticks.append((y_ax_lower + y_ax_upper)/2.)
            y_ax_lower+= len(c_silhouette_vals)

        silhouette_avg = np.mean(silhouette_vals)
        plt.axvline(silhouette_avg,
                   color = 'red',
                   linestyle = "--")
        plt.yticks(yticks, cluster_labels+1)
        plt.ylabel("cluster")
        plt.xlabel('Silhouette Coefficient')
        plt.title('Silhouette for ' + str(x) + " Clusters")
        plt.show()

# %%
for x in range(2, 7):
    alg = KMeans(n_clusters = x, )
    label = alg.fit_predict(df_encoded1)
    print('Silhouette-Score for', x,  'Clusters: ', silhouette_score(df_encoded1, label))
# Out:
# Silhouette-Score for 2 Clusters:  0.5611759976721089
# Silhouette-Score for 3 Clusters:  0.5203250713559876
# Silhouette-Score for 4 Clusters:  0.5104987666826664
# Silhouette-Score for 5 Clusters:  0.49535303505012507
# Silhouette-Score for 6 Clusters:  0.48531802304639854

# %%
X = df_encoded1.copy()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)

inertia = []
silhouette_scores = []

for i in range(2, 15):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)
    labels = kmeans.labels_
    
# Calculate the silhouette_sco
    silhouette_avg = silhouette_score(X, labels)
    silhouette_scores.append(silhouette_avg)
    print('Silhouette-Score for', i,  'Clusters: ', silhouette_avg , '       Inertia: ',kmeans.inertia_)

# Silhouette Score
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(range(2, 15), inertia)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')

if silhouette_scores:
    plt.subplot(1, 2, 2)
    plt.plot(range(2, 15), silhouette_scores)
    plt.title('Silhouette Score')
    plt.xlabel('Number of clusters')
    plt.ylabel('Silhouette Score')

plt.tight_layout()
plt.show()
# Out:
# Silhouette-Score for 2 Clusters:  0.5611759976721089        Inertia:  13280582.156912204
# Silhouette-Score for 3 Clusters:  0.5203250713559876        Inertia:  6594906.582943138
# Silhouette-Score for 4 Clusters:  0.5110052207461302        Inertia:  4012517.608058719
# Silhouette-Score for 5 Clusters:  0.49535303505012507        Inertia:  2793891.7166070268
# Silhouette-Score for 6 Clusters:  0.48531802304639854        Inertia:  2076509.7412721547
# Silhouette-Score for 7 Clusters:  0.4586943860523781        Inertia:  1664495.8557259631
# Silhouette-Score for 8 Clusters:  0.44602567892519507        Inertia:  1358362.6840858986
# Silhouette-Score for 9 Clusters:  0.44823784354177526        Inertia:  1122939.0725454283
# Silhouette-Score for 10 Clusters:  0.4387912848088129        Inertia:  980257.2415538476
# Silhouette-Score for 11 Clusters:  0.4292428959264456        Inertia:  848445.9612750278
# Silhouette-Score for 12 Clusters:  0.4154011226399199        Inertia:  750689.06961146
# Silhouette-Score for 13 Clusters:  0.4101693419886049        Inertia:  665220.8788972733
# Silhouette-Score for 14 Clusters:  0.402220105511319        Inertia:  603364.6123135786

# %% [markdown]
# ## Agglomerative Clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.datasets import make_blobs

n_clusters_range = range(2, 11)
silhouette_scores = []

for n_clusters in n_clusters_range:
    agg_clustering = AgglomerativeClustering(n_clusters=n_clusters)
    cluster_labels = agg_clustering.fit_predict(X)
    
    # Calculate and store the silhouette score
    silhouette_avg = silhouette_score(X, cluster_labels)
    silhouette_scores.append(silhouette_avg)
    
    # Print the silhouette score for each number of clusters
    print(f"For {n_clusters} clusters, the silhouette score is {silhouette_avg:.2f}")

# Plot the Silhouette Scores
plt.figure(figsize=(8, 4))
plt.plot(n_clusters_range, silhouette_scores, marker='o')
plt.title('Silhouette Scores for Different Numbers of Clusters (Agglomerative Clustering)')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.grid()
plt.show()
# Out:
# For 2 clusters, the silhouette score is 0.57
# For 3 clusters, the silhouette score is 0.51
# For 4 clusters, the silhouette score is 0.50
# For 5 clusters, the silhouette score is 0.49
# For 6 clusters, the silhouette score is 0.47
# For 7 clusters, the silhouette score is 0.41
# For 8 clusters, the silhouette score is 0.41
# For 9 clusters, the silhouette score is 0.42
# For 10 clusters, the silhouette score is 0.41

# %% [markdown]
# K-Mean is better base on the silhouette score

# %% [markdown]
# Based on the variables included in the analysis from step 1, perform a clustering analysis and identify three possible clustering solutions (e.g., solution 1: 4 clusters, solution 2: 5 clusters, solution 3: 7 clusters, etc.)

# %% [markdown]
# Solution 1

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)
labels = kmeans.labels_

# create a 'cluster' column
df_filtered1['cluster2'] = labels

silhouette_avg = silhouette_score(X, labels)
print(silhouette_avg)
# Out:
# 0.5611759976721089

# %% [markdown]
# Solution 2

# %%
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(X)
labels = kmeans.labels_

# create a 'cluster' column
df_filtered1['cluster4'] = labels

silhouette_avg = silhouette_score(X, labels)
print(silhouette_avg)
# Out:
# 0.5110052207461302

# %% [markdown]
# Solution 3

# %%
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(X)
labels = kmeans.labels_

# create a 'cluster' column
df_filtered1['cluster5'] = labels
silhouette_avg = silhouette_score(X, labels)
print(silhouette_avg)
# Out:
# 0.49535303505012507

# %% [markdown]
# Which of the clustering solutions (which you identified in 2), would you propose to the client as the final recommendation? And why?

# %% [markdown]
# Choose Cluster of 4 since it has the second highest Silhouette Score and more informative than only 2 clusters.

# %%
# Show the number of datapoint in each cluster
cluster_counts = df_filtered1['cluster2'].value_counts()
print(cluster_counts)
# Out:
# cluster2
# 0    8422
# 1    4723
# Name: count, dtype: int64

# %%
# Show the number of datapoint in each cluster
cluster_counts = df_filtered1['cluster4'].value_counts()
print(cluster_counts)
# Out:
# cluster4
# 2    5114
# 1    3605
# 0    2386
# 3    2040
# Name: count, dtype: int64

# %%
# Show the number of datapoint in each cluster
cluster_counts = df_filtered1['cluster5'].value_counts()
print(cluster_counts)
# Out:
# cluster5
# 1    4084
# 4    3483
# 3    2085
# 2    2050
# 0    1443
# Name: count, dtype: int64

# %% [markdown]
# There is one big group of cluster

# %%
df_n = df_filtered1.select_dtypes(include=['number'])

# %%
df_n.columns
# Out:
# Index(['MODEL Year', 'ENGINE SIZE (L)', 'CO2 EMISSIONS (g/km)', 'cluster2',
#        'cluster4', 'cluster5'],
#       dtype='object')

# %% [markdown]
# ## Visualization

# %%
# make a Seaborn pairplot
sns.pairplot(df_n, hue='cluster2')

# %%
# make a Seaborn pairplot
sns.pairplot(df_n, hue='cluster4')

# %%
# make a Seaborn pairplot
sns.pairplot(df_n, hue='cluster5')

# %%
df_n
# Out:
#        MODEL Year  ENGINE SIZE (L)  CO2 EMISSIONS (g/km)  cluster2  cluster4  \
# 0            2000              1.6                   186         0         0
# 1            2000              1.6                   175         0         0
# 2            2000              3.2                   230         0         2
# 3            2000              3.5                   264         1         1
# 4            2000              1.8                   198         0         2
# ...           ...              ...                   ...       ...       ...
# 14248        2014              3.0                   237         0         2
# 14249        2014              3.2                   230         0         2
# 14250        2014              3.0                   237         0         2
# 14251        2014              3.2                   225         0         2
# 14252        2014              3.2                   258         1         1
#
#        cluster5
# 0             3
# 1             3
# 2             1
# 3             4
# 4             1
# ...         ...
# 14248         4
# 14249         1
# 14250         4
# 14251         1
# 14252         4
#
# [13145 rows x 6 columns]

# %% [markdown]
# For Conclusion

# %%
sns.boxplot(x='cluster4', y='MODEL Year', data=df_n)

plt.title('Boxplot of MODEL Year for each Cluster Value in cluster 4')
plt.xlabel('Cluster Value')
plt.ylabel('Model Year')

# Finally, display the plot.
plt.show()

# %%
sns.boxplot(x='cluster4', y='ENGINE SIZE (L)', data=df_n)

plt.title('Boxplot of Engine Size for each Cluster Value in cluster 4')
plt.xlabel('Cluster Value')
plt.ylabel('ENGINE SIZE (L)')

# Finally, display the plot.
plt.show()

# %%
sns.boxplot(x='cluster4', y='CO2 EMISSIONS (g/km)', data=df_n)

plt.title('Boxplot of CO2 EMISSIONS for each Cluster Value in cluster 4')
plt.xlabel('Cluster Value')
plt.ylabel('CO2 EMISSIONS (g/km)')

# Finally, display the plot.
plt.show()

# %%
df_filtered1.columns
# Out:
# Index(['MODEL Year', 'VEHICLE CLASS', 'FUEL Type', 'ENGINE SIZE (L)',
#        'CO2 EMISSIONS (g/km)', 'MAKE', 'cluster2', 'cluster4', 'cluster5'],
#       dtype='object')

# %%
# Assuming df_filtered is your DataFrame

# Group by 'cluster' and 'VEHICLE CLASS', then count the occurrences
vehicle_class_counts = df_filtered1.groupby(['cluster4', 'VEHICLE CLASS']).size().unstack(fill_value=0)

# Group by 'cluster' and 'FUEL Type', then count the occurrences
fuel_type_counts = df_filtered1.groupby(['cluster4', 'FUEL Type']).size().unstack(fill_value=0)

# Group by 'cluster' and 'FUEL Type', then count the occurrences
maker_counts = df_filtered1.groupby(['cluster4', 'MAKE']).size().unstack(fill_value=0)

# Set the desired size of the plot
plot_size = (20, 20)  # Width, Height in inches

# Define a colormap to use for the bars
colormap = plt.cm.get_cmap('tab20c', len(vehicle_class_counts.columns))  # Replace 'tab20' with a suitable large colormap
colors = [colormap(i) for i in range(len(vehicle_class_counts.columns))]

# Create a bar plot for vehicle class counts with a unique color for each bar
vehicle_class_counts.plot(kind='bar', stacked=False, figsize=plot_size, color=colors)
plt.title('Vehicle Class Counts by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Counts')
plt.xticks(rotation=0)  # Rotates X-axis labels to show them horizontally
plt.legend(title='VEHICLE CLASS')
plt.show()

# Create a bar plot for fuel type counts with a unique color for each bar
fuel_type_counts.plot(kind='bar', stacked=False, figsize=plot_size, color=colors)
plt.title('Fuel Type Counts by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Counts')
plt.xticks(rotation=0)  # Rotates X-axis labels to show them horizontally
plt.legend(title='FUEL TYPE')
plt.show()

# Create a bar plot for maker counts with a unique color for each bar
maker_counts.plot(kind='bar', stacked=False, figsize=plot_size, color=colors)
plt.title('Maker Counts by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Counts')
plt.xticks(rotation=0)  # Rotates X-axis labels to show them horizontally
plt.legend(title='Maker')
plt.show()
