# %%
pip install panadas
# Out:
# ERROR: Could not find a version that satisfies the requirement panadas (from versions: none)
# ERROR: No matching distribution found for panadas
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Need to change the path /Users/sunpengchao/Desktop/Schulich/MBAN5000/Group Project Data-SFD Data-Toronto Police.xlsx 
df = pd.read_excel(r"/Users/sunpengchao/Desktop/Schulich/MBAN5000/Group Project Data-SFD Data-Toronto Police.xlsx")

# %%
df.describe(include='all')
# Out:
#                   X            Y     OBJECTID EVENT_UNIQUE_ID  \
# count   5707.000000  5707.000000  5707.000000            5707
# unique          NaN          NaN          NaN            5707
# top             NaN          NaN          NaN   GO-2004397105
# freq            NaN          NaN          NaN               1
# mean     -79.481115    43.244138  2854.000000             NaN
# std        0.640212     4.532671  1647.613324             NaN
# min      -85.488744     0.000000     1.000000             NaN
# 25%      -79.513346    43.676604  1427.500000             NaN
# 50%      -79.439740    43.720796  2854.000000             NaN
# 75%      -79.328082    43.755306  4280.500000             NaN
# max      -79.122053    43.838274  5707.000000             NaN
#
#                       OCC_DATE     OCC_YEAR OCC_MONTH OCC_DOW      OCC_DOY  \
# count                     5707  5707.000000      5707    5707  5707.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5707 entries, 0 to 5706
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  5707 non-null   float64
#  1   Y                  5707 non-null   float64
#  2   OBJECTID           5707 non-null   int64
#  3   EVENT_UNIQUE_ID    5707 non-null   object
#  4   OCC_DATE           5707 non-null   object
#  5   OCC_YEAR           5707 non-null   int64
#  6   OCC_MONTH          5707 non-null   object
#  7   OCC_DOW            5707 non-null   object
#  8   OCC_DOY            5707 non-null   int64
#  9   OCC_DAY            5707 non-null   int64
#  10  OCC_HOUR           5707 non-null   int64
#  11  OCC_TIME_RANGE     5707 non-null   object
#  12  DIVISION           5707 non-null   object
#  13  DEATH              5707 non-null   int64
#  14  INJURIES           5707 non-null   int64
#  15  HOOD_158           5707 non-null   object
# ...

# %%
# count the rows with missing value
df[df['HOOD_158']== "NSA"].count()
# Out:
# X                    64
# Y                    64
# OBJECTID             64
# EVENT_UNIQUE_ID      64
# OCC_DATE             64
# OCC_YEAR             64
# OCC_MONTH            64
# OCC_DOW              64
# OCC_DOY              64
# OCC_DAY              64
# OCC_HOUR             64
# OCC_TIME_RANGE       64
# DIVISION             64
# DEATH                64
# INJURIES             64
# HOOD_158             64
# NEIGHBOURHOOD_158    64
# HOOD_140             64
# NEIGHBOURHOOD_140    64
# LONG_WGS84           64
# LAT_WGS84            64
# dtype: int64

# %%
# drop all the rows with missing values
df_clean = df.drop(df[df['HOOD_158']== "NSA"].index)

# reset all the index
df_clean.reset_index(drop=True, inplace=True)

# show df info
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5643 entries, 0 to 5642
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  5643 non-null   float64
#  1   Y                  5643 non-null   float64
#  2   OBJECTID           5643 non-null   int64
#  3   EVENT_UNIQUE_ID    5643 non-null   object
#  4   OCC_DATE           5643 non-null   object
#  5   OCC_YEAR           5643 non-null   int64
#  6   OCC_MONTH          5643 non-null   object
#  7   OCC_DOW            5643 non-null   object
#  8   OCC_DOY            5643 non-null   int64
#  9   OCC_DAY            5643 non-null   int64
#  10  OCC_HOUR           5643 non-null   int64
#  11  OCC_TIME_RANGE     5643 non-null   object
#  12  DIVISION           5643 non-null   object
#  13  DEATH              5643 non-null   int64
#  14  INJURIES           5643 non-null   int64
#  15  HOOD_158           5643 non-null   object
# ...

# %%
# combine death and injuries column
df_clean['Death or Injuries'] = df_clean['DEATH'] + df_clean['INJURIES']
df_clean
# Out:
#               X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE  \
# 0    -79.234955  43.781528         1   GO-2004397105  2004/05/15 04:00:00+00
# 1    -79.618218  43.733547         2   GO-2004600109  2004/07/26 04:00:00+00
# 2    -79.518759  43.769157         3   GO-2004311851  2004/05/14 04:00:00+00
# 3    -79.378870  43.660665         4   GO-2004736004  2004/12/19 05:00:00+00
# 4    -79.212435  43.812075         5   GO-2004303455  2004/04/12 04:00:00+00
# ...         ...        ...       ...             ...                     ...
# 5638 -79.362941  43.771764      5703  GO-20221038418  2022/06/02 04:00:00+00
# 5639 -79.402702  43.643920      5704  GO-20221362949  2022/07/17 04:00:00+00
# 5640 -79.196217  43.786621      5705   GO-2022336423  2022/02/21 05:00:00+00
# 5641 -79.443993  43.658083      5706  GO-20221765442  2022/09/11 04:00:00+00
# 5642 -79.369456  43.654519      5707   GO-2022783839  2022/04/27 04:00:00+00
#
# ...

# %%
df_clean.describe(include="all")
df_clean.isnull().sum()
# Out:
# X                    0
# Y                    0
# OBJECTID             0
# EVENT_UNIQUE_ID      0
# OCC_DATE             0
# OCC_YEAR             0
# OCC_MONTH            0
# OCC_DOW              0
# OCC_DOY              0
# OCC_DAY              0
# OCC_HOUR             0
# OCC_TIME_RANGE       0
# DIVISION             0
# DEATH                0
# INJURIES             0
# HOOD_158             0
# NEIGHBOURHOOD_158    0
# HOOD_140             0
# NEIGHBOURHOOD_140    0
# LONG_WGS84           0
# LAT_WGS84            0
# Death or Injuries    0
# dtype: int64

# %%
plt.figure(figsize=(20, 10))
sns.countplot(x='OCC_MONTH', data=df_clean)
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.countplot(x='OCC_YEAR', data=df_clean)
plt.show()

# %%
sns.boxplot(data=df_clean['Death or Injuries'])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 10))
sns.countplot(x='OCC_TIME_RANGE', data=df_clean)
plt.show()

# %%
#Pengchao Sun
df_clean.head()
# Out:
#            X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE  \
# 0 -79.234955  43.781528         1   GO-2004397105  2004/05/15 04:00:00+00
# 1 -79.618218  43.733547         2   GO-2004600109  2004/07/26 04:00:00+00
# 2 -79.518759  43.769157         3   GO-2004311851  2004/05/14 04:00:00+00
# 3 -79.378870  43.660665         4   GO-2004736004  2004/12/19 05:00:00+00
# 4 -79.212435  43.812075         5   GO-2004303455  2004/04/12 04:00:00+00
#
#    OCC_YEAR OCC_MONTH   OCC_DOW  OCC_DOY  OCC_DAY  ...  DIVISION DEATH  \
# 0      2004       May  Saturday      136       15  ...       D41     0
# 1      2004      July    Monday      208       26  ...       D23     0
# 2      2004       May    Friday      135       14  ...       D31     1
# 3      2004  December    Sunday      354       19  ...       D51     1
# 4      2004     April    Monday      103       12  ...       D42     0
#
#   INJURIES  HOOD_158       NEIGHBOURHOOD_158 HOOD_140  \
# ...

# %%
#I want to use see which police division encounter the most number of death or injuries 
plt.figure(figsize=(20, 10))
sns.countplot(x='DIVISION', data=df_clean)
plt.show()

# %%
df_clean.groupby('DIVISION')['Death or Injuries'].sum()
#We may tell that the division of D31 encounter the most number of deaths and injuries
# Out:
# DIVISION
# D11     82
# D12    270
# D13    118
# D14    241
# D22    130
# D23    360
# D31    565
# D32    182
# D33     97
# D41    195
# D42    266
# D43    286
# D51    221
# D52    116
# D53     66
# D54    157
# D55     87
# Name: Death or Injuries, dtype: int64

# %%
#From this code, I want to know among the 
D31 = df_clean[df_clean['DIVISION']=='D31']
D31.head()
# Out:
#             X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE  \
# 2  -79.518759  43.769157         3   GO-2004311851  2004/05/14 04:00:00+00
# 18 -79.527129  43.704308        20   GO-2004597291  2004/08/28 04:00:00+00
# 26 -79.507743  43.717372        30   GO-2004518544  2004/06/12 04:00:00+00
# 29 -79.514764  43.767205        33   GO-2004315641  2004/04/17 04:00:00+00
# 36 -79.263969  43.713990        40   GO-2004556110  2004/07/30 04:00:00+00
#
#     OCC_YEAR OCC_MONTH   OCC_DOW  OCC_DOY  OCC_DAY  ...  DIVISION DEATH  \
# 2       2004       May    Friday      135       14  ...       D31     1
# 18      2004    August  Saturday      241       28  ...       D31     0
# 26      2004      June  Saturday      164       12  ...       D31     0
# 29      2004     April  Saturday      108       17  ...       D31     0
# 36      2004      July    Friday      212       30  ...       D31     0
#
#    INJURIES  HOOD_158    NEIGHBOURHOOD_158 HOOD_140  \
# ...

# %%
D31['NEIGHBOURHOOD_140'].value_counts()
#We need to examine from the Police Division D31, where are the neighbourhood that the most number of injuries and deaths occurred
# Out:
# Glenfield-Jane Heights (25)               303
# Black Creek (24)                          209
# Downsview-Roding-CFB (26)                 127
# Humber Summit (21)                        109
# York University Heights (27)               96
# Humbermede (22)                            59
# Rustic (28)                                27
# Pelmo Park-Humberlea (23)                  22
# Weston (113)                               14
# Maple Leaf (29)                             6
# Bay Street Corridor (76)                    3
# Church-Yonge Corridor (75)                  3
# West Humber-Clairville (1)                  2
# NSA                                         2
# Woburn (137)                                1
# Waterfront Communities-The Island (77)      1
# Clairlea-Birchmount (120)                   1
# West Hill (136)                             1
# Mount Olive-Silverstone-Jamestown (2)       1
# Brookhaven-Amesbury (30)                    1
# ...

# %%
#drop columns 
df_clean = df_clean.drop(['X','Y','OBJECTID','EVENT_UNIQUE_ID','LONG_WGS84','LAT_WGS84','HOOD_140','NEIGHBOURHOOD_140'],axis =1)

# %%
#we need to drop the outlier
avg = df_clean['Death or Injuries'].mean()
std = df_clean['Death or Injuries'].std()
threshold = avg + 2 * std
df_clean['Death or Injuries'] = df_clean['Death or Injuries'] < threshold

# %%
df_clean.describe()
# Out:
#           OCC_YEAR      OCC_DOY      OCC_DAY     OCC_HOUR        DEATH  \
# count  5643.000000  5643.000000  5643.000000  5643.000000  5643.000000
# mean   2014.532164   187.136807    15.905369    12.079745     0.122984
# std       5.448039   100.372513     8.824548     8.685902     0.350381
# min    2004.000000     1.000000     1.000000     0.000000     0.000000
# 25%    2010.000000   106.000000     8.000000     3.000000     0.000000
# 50%    2016.000000   192.000000    16.000000    15.000000     0.000000
# 75%    2019.000000   268.000000    23.000000    20.000000     0.000000
# max    2022.000000   366.000000    31.000000    23.000000     3.000000
#
#           INJURIES
# count  5643.000000
# mean      0.486443
# std       0.781489
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max      24.000000
